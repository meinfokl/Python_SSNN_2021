# %%
import matplotlib.pyplot as plt
import math
import numpy as np

D = 50   # range
Dx = 0.5  # granularity
C = [[0,D],[D,0]]   # centers 
Rc = [25,25]    # circle center
Rc = [25,25]    # circle center
Rr = 10   # circle radius

X = []
Y = []
Xc = []
Yc = []
Xo = []
Yo = []
Xoc = []
Yoc = []

for i in range(int(D/Dx)):
    x = 0 + i*Dx
    for j in range(int(D/Dx)):
        y = 0 + j*Dx
        if (x - Rc[0])**2 + (y-Rc[1])**2 < Rr**2:
            xr = math.sqrt((x - C[0][0])**2 + (y-C[0][1])**2)
            yr = math.sqrt((x - C[1][0])**2 + (y-C[1][1])**2)
            X.append(xr)
            Y.append(yr)
            Xo.append(x)
            Yo.append(y)
        else:
            xr = math.sqrt((x - C[0][0])**2 + (y-C[0][1])**2)
            yr = math.sqrt((x - C[1][0])**2 + (y-C[1][1])**2)
            Xc.append(xr)
            Yc.append(yr)
            Xoc.append(x)
            Yoc.append(y)
            
            
plt.scatter(Xo,Yo,c="red")
plt.scatter(Xoc,Yoc,c="blue")
plt.show()
plt.scatter(X,Y,c="red")
plt.scatter(Xc,Yc,c="blue")
plt.show()

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

D = 50   # range
Dx = 0.5  # granularity
C = [[0,D],[D,0]]   # centers 
P = [4,20]   # point 
V = [25,15]    # normal vector


X = []
Y = []
Xo = []
Yo = []

for i in range(int(D/Dx)):
    x = 0 + i*Dx
    for j in range(int(D/Dx)):
        y = 0 + j*Dx
        if (x - P[0])*V[0] + (y-P[1])*V[1] > 0:
            xr = math.sqrt((x - C[0][0])**2 + (y-C[0][1])**2)
            yr = math.sqrt((x - C[1][0])**2 + (y-C[1][1])**2)
            X.append(xr)
            Y.append(yr)
            Xo.append(x)
            Yo.append(y)
            
plt.scatter(Xo,Yo)
plt.show()
plt.scatter(X,Y)
plt.show()
