# %%
# Sphere-Plane NN model

import matplotlib.pyplot as plt 
from math import exp
from random import seed
from random import random
from random import randint
import matplotlib.lines as lines 

import math
 
# Initialize a network


class neuron_s():
    
    def __init__(self, n_inputs,c):
        self.inputs = [0 for _ in range(n_inputs)]
        self.weights = [random() for _ in range(n_inputs)]
        s1 = sum([x*x for x in self.weights])
        s2 = math.sqrt(s1)
        self.weights = [x /s2 for x in self.weights ]

        self.delta = 0
        self.output = 0
        self.A = 2 + 0.6*random()
        self.R = .2 + 4*random()
        self.C = c
    
    def activate(self):
        N = len(self.weights)
        y1 = sum([self.inputs[i]* self.inputs[i] for i in range(N) ])
        y2 = sum([self.inputs[i]* self.weights[i] for i in range(N) ])
        activation = - (y1 - 2*(self.A + self.R)*y2 + self.A*self.A + 2*self.A*self.R)
        #print (self.weights, "C:", self.weights[0]*(self.A +self.R), self.weights[1]*(self.A +self.R), activation)
        return activation
    
    def transfer(self,activation):
        self.output = 1.0 / (1.0 + exp(-.5*activation)) 
        return self.output

    def transfer_derivative(self):
        return .5*self.output * (1.0 - self.output)

    # Calculate the derivative of the activation function
    def activation_derivate_by_input(self, idx):
        return 2*self.inputs[idx] - 2*(self.A + self.R)*self.weights[idx]

    def activation_derivate_by_weight(self, idx):
        return  - 2*(self.A + self.R)*self.inputs[idx]

    def activation_derivate_by_A(self):
        N = len(self.inputs)
        s1 = sum([self.inputs[i]*self.weights[i] for i in range(N)])
        return -2*s1 + 2*(self.A + self.R)

    def activation_derivate_by_R(self):
        N = len(self.inputs)
        s1 = sum([self.inputs[i]*self.weights[i] for i in range(N)])
        return -2*s1 + 2*(self.A)
    
    def print_neuron_param(self):
        print(self.weights, self.A, self.R,self.C)

    def update_weights(self, l_rate):
        for j in range(len(self.weights)):
            self.weights[j] -= l_rate * self.delta * self.activation_derivate_by_weight(j)
        self.A -= l_rate * self.delta*self.activation_derivate_by_A()
        self.R -= 1.5*l_rate * self.delta*self.activation_derivate_by_R()
        s1 = sum([x*x for x in self.weights])
        s2 = math.sqrt(s1)
        self.weights = [x /s2 for x in self.weights ]
        
    def draw_neuron(self, axes, plt):
        cl = 'blue' if self.C > 0 else 'red'
        cc = plt.Circle( ((self.A+self.R)*self.weights[0], (self.A+self.R)*self.weights[1] ), self.R ,fill = False,color=cl )   
        axes.add_artist( cc)    
        
        
class neuron_l():
    
    def __init__(self, n_inputs):
        self.inputs = [0 for _ in range(n_inputs)]
        self.weights = [random() for _ in range(n_inputs)]
        self.delta = 0
        self.output = 0
        self.A = random()
    
    def activate(self):
        N = len(self.weights)
        y1 = sum([self.inputs[i]* self.weights[i] for i in range(N) ])
        activation = (y1  + self.A) 
        return activation
    
    def transfer(self,activation):
        self.output = 1.0 / (1.0 + exp(-activation)) 
        return self.output

    def transfer_derivative(self):
        return self.output * (1.0 - self.output)

    # Calculate the derivative of the activation function
    def activation_derivate_by_input(self, idx):
        return self.weights[idx]

    def activation_derivate_by_weight(self, idx):
        return  self.inputs[idx]

    def activation_derivate_by_A(self):
        return 1
    
    def print_neuron_param(self):
        print(self.weights, self.A)

    def update_weights(self, l_rate):
        for j in range(len(self.weights)):
            self.weights[j] += l_rate * self.delta * self.activation_derivate_by_weight(j)
        self.A += l_rate * self.delta*self.activation_derivate_by_A()

    def draw_neuron(self, axes, plt):
        cl = 'black"'
        x1 = -2
        y1 = (self.A - self.weights[0]*x1) / self.weights[1]
        x2 = 8
        y2 = (self.A - self.weights[0]*x2) / self.weights[1]
        line   = plt.Line2D([x1,x2],[y1,y2],mfc ='green')
        print ("line",[x1,x2],[y1,y2],"w",self.weights)
        plt.gca().add_line(line)    
        
        
class SSNN_network():
    
    def __init__ (self, n_inputs, hidden_nmode, outputs_nmode, outputs_category):
        self.layers = []
        n_outputs = len(outputs_nmode)
        n_hiddens = len(hidden_nmode)
        self.outputs = outputs_category
        self.HL = -1
        self.OL = 0
        self.layers.append([])
        if n_hiddens > 0:
            self.layers.append([])
            self.HL = 0
            self.OL = 1
            for i in range(n_hiddens):
                if hidden_nmode[i] == 'S': 
                    self.layers[HL].append(neuron_s(n_inputs,0))
                else:
                    self.layers[HL].append(neuron_l(n_inputs))
            for i in range(n_outputs):
                if outputs_nmode[i] == 'S': 
                    self.layers[self.OL].append(neuron_s(n_hiddens,outputs_category[i]))
                else:
                    self.layers[self.OL].append(neuron_l(n_hiddens))
        else:
            for i in range(n_outputs):
                if outputs_nmode[i] == 'S': 
                    self.layers[self.OL].append(neuron_s(n_inputs,outputs_category[i]))
                else:
                    self.layers[self.OL].append(neuron_l(n_inputs))
        
    def forward_propagate(self, row):
        for neuron in self.layers[0]:
            for i in range(len(row)-1):
                neuron.inputs[i] = row[i]

        for l in range(len(self.layers)):
            layer = self.layers[l]
            for neuron in layer:
                activation = neuron.activate()
                neuron.transfer(activation)
            if l < self.OL:
                for neuron in self.layers[l+1]:
                    for i in range(len(self.layers[l])):
                        neuron2 = self.layers[l][i]
                        neuron.inputs[i] = neuron2.output

            outputs = []
            for neuron in self.layers[self.OL]:
                outputs.append(neuron.output)
        return outputs
     
    
    def backward_propagate_error(self, expected):
        for i in reversed(range(len(self.layers))):
            layer = self.layers[i]
            errors = list()
            if i != self.OL:
                for j in range(len(layer)):
                    error = 0.0
                    for neuron in self.layers[i + 1]:
                        error += (neuron.activation_derivate_by_input(j) * neuron.delta)
                    errors.append(error)
            else:
                for j in range(len(layer)):
                    neuron = layer[j]
                    #exp = expected[j] if neuron["C"] == '0' else (1-expected[j])
                    exp = expected[j] 
                    errors.append(exp - neuron.output)
            for j in range(len(layer)):
                neuron = layer[j]
                neuron.delta = errors[j] * neuron.transfer_derivative()
                
    def update_weights(self, l_rate):
        for i in range(len(self.layers)):
            for neuron in self.layers[i]:
                neuron.update_weights(l_rate);

    def train_network(self, train, l_rate, n_epoch, drf = 5):
        n_outputs = len(self.outputs)
        self.draw_network( train)
        self.print_network_param()
        for epoch in range(n_epoch):
            sum_error = 0
            for row in train:
                voutputs = self.forward_propagate( row)
                expected = [0 for i in range(n_outputs)]
                for i in range(n_outputs):
                    if self.outputs[i] == row[-1]:
                        expected[i] = 1
                sum_error += sum([(expected[i]-voutputs[i])**2 for i in range(len(expected))])
                self.backward_propagate_error( expected)
                self.update_weights(l_rate)
            print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
            if epoch % drf == 0:
                self.draw_network( train)
                self.print_network_param()
              
            
    def draw_network (self, train):
        figure, axes = plt.subplots()
        axes.set_aspect( 1 )
        for i in range(len(self.layers[self.OL])):
            sn = self.layers[self.OL][i]
            sn.draw_neuron(axes, plt)
        for i in range(len(train)):
            cl = 'blue' if train[i][2] > 0 else 'red'
            cc = plt.Circle( (train[i][0], train[i][1] ), 0.1 ,fill = True, color =cl )   
            axes.add_artist( cc)        

        plt.xlim( -2 ,8 ) 
        plt.ylim( -2 , 8) 
        plt.title( 'Circle' ) 
        plt.show()            
                
    def print_network_param(self):
        for layer in self.layers:
            print ("Layer ---------------")
            for neuron in layer:
                neuron.print_neuron_param()
                
    def test_network(self, train):
        print (self.outputs)
        n_outputs = len(self.outputs)
        dbok = 0
        for row in train:
            voutputs = self.forward_propagate( row)
            expected = [0 for i in range(n_outputs)]
            idx = voutputs.index(max(voutputs))
            if self.outputs[idx] == row[-1]:
                dbok += 1
            print (row, voutputs)
        print ("accuray:", dbok / len(train))

# %%
def set_network_1(network):
    
    network.layers[0][0].weights = [1,1]
    network.layers[0][0].A = 1.
    network.layers[0][0].R = 1.
    network.layers[0][1].weights = [0,4]
    network.layers[0][1].A = 1.5
    network.layers[0][1].R = 2.
    network.layers[0][2].weights = [4,0]
    network.layers[0][2].A = 1.5
    network.layers[0][2].R = 2.
    
    
    for layer in network.layers:
        db = 0
        for neuron in layer:
            s1 = sum([x*x for x in neuron.weights])
            s2 = math.sqrt(s1)
            neuron.weights = [x /s2 for x in neuron.weights ]
               
    return network

T = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1],
    [0.673756466,5.508563011,1],
    [1.373756466,6.108563011,1],
    [1.93756466,7.108563011,1] 
    ]
n_inputs = len(T[0]) - 1
network = SSNN_network(n_inputs, [],['S','S','S'],[0,1,1])
#network = set_network_1(network)
#network.print_network_param()
network.train_network( T, 0.05, 150, 10)
network.test_network(T)
# Out:
# Layer ---------------
# [0.8612205686582048, 0.5082313765599662] 2.3065827662354175 0.23809603081279757 0
# [0.7370782209713252, 0.6758074401556603] 2.551637890764357 3.8103085116522655 1
# [0.7762808004445784, 0.6303872768870933] 2.459495116218431 0.43691432727214324 1
# >epoch=0, lrate=0.050, error=17.003
# Layer ---------------
# [0.8274112297715331, 0.5615965249607224] 2.3265654142225483 0.27843886865450856 0
# [0.651372188875436, 0.7587583749518838] 2.5853205039404092 3.8574576253426804 1
# [0.7965756222602848, 0.6045388970286691] 2.459715318112766 0.42589793335118636 1
# >epoch=1, lrate=0.050, error=16.917
# >epoch=2, lrate=0.050, error=16.222
# >epoch=3, lrate=0.050, error=16.043
# >epoch=4, lrate=0.050, error=15.733
# >epoch=5, lrate=0.050, error=15.637
# >epoch=6, lrate=0.050, error=15.248
# >epoch=7, lrate=0.050, error=15.392
# >epoch=8, lrate=0.050, error=14.743
# >epoch=9, lrate=0.050, error=15.065
# >epoch=10, lrate=0.050, error=14.407
# Layer ---------------
# [0.6698357121036174, 0.7425093391942218] 2.522464810135853 0.7984946926540241 0
# [0.5991545192133493, 0.8006334130588233] 2.947168383404718 4.641014439363455 1
# [0.9511074180244482, 0.3088602910360405] 2.4851712576310883 0.40326520768913865 1
# >epoch=11, lrate=0.050, error=14.442
# >epoch=12, lrate=0.050, error=14.250
# >epoch=13, lrate=0.050, error=13.952
# >epoch=14, lrate=0.050, error=14.130
# >epoch=15, lrate=0.050, error=13.684
# >epoch=16, lrate=0.050, error=13.906
# >epoch=17, lrate=0.050, error=13.499
# >epoch=18, lrate=0.050, error=13.585
# >epoch=19, lrate=0.050, error=13.697
# >epoch=20, lrate=0.050, error=13.585
# Layer ---------------
# [0.6349678003341751, 0.772538602620464] 2.614826365802282 1.4093009350756056 0
# [0.5977253874693705, 0.8017009175338337] 3.040913460293686 5.232869173765845 1
# [0.9826451175545051, 0.18549547958452584] 2.520244885740916 0.4428061248125112 1
# >epoch=21, lrate=0.050, error=13.653
# >epoch=22, lrate=0.050, error=13.580
# >epoch=23, lrate=0.050, error=13.427
# >epoch=24, lrate=0.050, error=13.188
# >epoch=25, lrate=0.050, error=12.878
# >epoch=26, lrate=0.050, error=12.816
# >epoch=27, lrate=0.050, error=12.775
# >epoch=28, lrate=0.050, error=12.737
# >epoch=29, lrate=0.050, error=12.702
# >epoch=30, lrate=0.050, error=12.668
# Layer ---------------
# [0.6239240413806408, 0.7814849906346562] 2.5136870750007585 1.79331224485447 0
# [0.6430591503971538, 0.7658165113723331] 3.105333551167048 5.519445296763978 1
# [0.990368207764208, 0.13845870521534795] 2.551128444705025 0.48552495996394246 1
# >epoch=31, lrate=0.050, error=12.636
# >epoch=32, lrate=0.050, error=12.605
# >epoch=33, lrate=0.050, error=12.575
# >epoch=34, lrate=0.050, error=12.547
# >epoch=35, lrate=0.050, error=12.520
# >epoch=36, lrate=0.050, error=12.494
# >epoch=37, lrate=0.050, error=12.469
# >epoch=38, lrate=0.050, error=12.446
# >epoch=39, lrate=0.050, error=12.424
# >epoch=40, lrate=0.050, error=12.405
# Layer ---------------
# [0.6250460273939149, 0.780587896164862] 2.3485530389774594 1.991824106153366 0
# [0.6404728962823278, 0.7679807739310447] 3.2191806552359163 5.546180924856705 1
# [0.9927562568908576, 0.12014580477092765] 2.581455322229703 0.5308788916460891 1
# >epoch=41, lrate=0.050, error=12.389
# >epoch=42, lrate=0.050, error=12.378
# >epoch=43, lrate=0.050, error=12.384
# >epoch=44, lrate=0.050, error=12.480
# >epoch=45, lrate=0.050, error=13.316
# >epoch=46, lrate=0.050, error=12.281
# >epoch=47, lrate=0.050, error=12.272
# >epoch=48, lrate=0.050, error=12.277
# >epoch=49, lrate=0.050, error=12.395
# >epoch=50, lrate=0.050, error=13.314
# Layer ---------------
# [0.6288697224118551, 0.7775106894658338] 2.1981737965623322 2.1133765994427285 0
# [0.696745274284886, 0.7173186340544061] 3.3122662604599817 5.801056621694068 1
# [0.9929926213062445, 0.11817636832866923] 2.6146130980404974 0.5830503336392452 1
# >epoch=51, lrate=0.050, error=12.357
# >epoch=52, lrate=0.050, error=13.256
# >epoch=53, lrate=0.050, error=12.319
# >epoch=54, lrate=0.050, error=13.266
# >epoch=55, lrate=0.050, error=12.549
# >epoch=56, lrate=0.050, error=12.125
# >epoch=57, lrate=0.050, error=12.127
# >epoch=58, lrate=0.050, error=12.908
# >epoch=59, lrate=0.050, error=12.199
# >epoch=60, lrate=0.050, error=11.949
# Layer ---------------
# [0.6317073135317096, 0.7752069852823503] 2.07464305601043 2.1894804288661693 0
# [0.6286581041090072, 0.7776818039134441] 3.4697902222022003 6.2075878399814375 1
# [0.9916090032940722, 0.12927329417221847] 2.654919757301278 0.6491652683004585 1
# >epoch=61, lrate=0.050, error=12.746
# >epoch=62, lrate=0.050, error=12.763
# >epoch=63, lrate=0.050, error=12.623
# >epoch=64, lrate=0.050, error=11.818
# >epoch=65, lrate=0.050, error=12.526
# >epoch=66, lrate=0.050, error=11.688
# >epoch=67, lrate=0.050, error=11.955
# >epoch=68, lrate=0.050, error=13.613
# >epoch=69, lrate=0.050, error=12.293
# >epoch=70, lrate=0.050, error=12.132
# Layer ---------------
# [0.6333175607938125, 0.7738920255372681] 1.9750058474750076 2.2375149510319967 0
# [0.5944035089809506, 0.8041669406977217] 3.7210717852651807 6.8000078135911055 1
# [0.9880610963976839, 0.154062551534781] 2.710723392994889 0.7444113146083641 1
# >epoch=71, lrate=0.050, error=11.333
# >epoch=72, lrate=0.050, error=11.384
# >epoch=73, lrate=0.050, error=12.038
# >epoch=74, lrate=0.050, error=11.460
# >epoch=75, lrate=0.050, error=12.004
# >epoch=76, lrate=0.050, error=11.979
# >epoch=77, lrate=0.050, error=12.697
# >epoch=78, lrate=0.050, error=12.187
# >epoch=79, lrate=0.050, error=11.123
# >epoch=80, lrate=0.050, error=11.526
# Layer ---------------
# [0.634175130753959, 0.773189435735641] 1.8939435765108186 2.2693488435206315 0
# [0.5234464519527811, 0.8520585730676294] 3.8193827535675218 7.42564219387453 1
# [0.98079002523763, 0.19506646660656235] 2.8043852190610288 0.911415064016815 1
# >epoch=81, lrate=0.050, error=11.765
# >epoch=82, lrate=0.050, error=11.114
# >epoch=83, lrate=0.050, error=11.787
# >epoch=84, lrate=0.050, error=11.037
# >epoch=85, lrate=0.050, error=11.564
# >epoch=86, lrate=0.050, error=11.953
# >epoch=87, lrate=0.050, error=10.831
# >epoch=88, lrate=0.050, error=10.728
# >epoch=89, lrate=0.050, error=10.658
# >epoch=90, lrate=0.050, error=10.758
# Layer ---------------
# [0.6346491882413848, 0.7728003674071015] 1.8269099850113855 2.2922312403399903 0
# [0.5419763030971442, 0.8403937689447446] 3.890949403540878 7.845539925727734 1
# [0.9709129091630011, 0.23943291925012783] 3.000213914563558 1.281422816151803 1
# >epoch=91, lrate=0.050, error=11.669
# >epoch=92, lrate=0.050, error=10.703
# >epoch=93, lrate=0.050, error=13.726
# >epoch=94, lrate=0.050, error=13.554
# >epoch=95, lrate=0.050, error=11.304
# >epoch=96, lrate=0.050, error=10.503
# >epoch=97, lrate=0.050, error=13.313
# >epoch=98, lrate=0.050, error=12.834
# >epoch=99, lrate=0.050, error=11.697
# >epoch=100, lrate=0.050, error=10.613
# Layer ---------------
# [0.6349387657585774, 0.7725624659126111] 1.7705184480390406 2.3100665290296347 0
# [0.5099641151423089, 0.8601956761499805] 4.075137661303944 8.642585872417285 1
# [0.9687943000732513, 0.24786610124335096] 3.349261273015086 2.007239079276431 1
# >epoch=101, lrate=0.050, error=11.563
# >epoch=102, lrate=0.050, error=10.031
# >epoch=103, lrate=0.050, error=10.435
# >epoch=104, lrate=0.050, error=8.574
# >epoch=105, lrate=0.050, error=7.639
# >epoch=106, lrate=0.050, error=7.433
# >epoch=107, lrate=0.050, error=7.304
# >epoch=108, lrate=0.050, error=6.865
# >epoch=109, lrate=0.050, error=6.571
# >epoch=110, lrate=0.050, error=6.350
# Layer ---------------
# [0.6351378184587786, 0.7723988293384599] 1.7223220564889428 2.32482789355924 0
# [0.6306898095103111, 0.7760350276758438] 4.371059269539191 9.078476744776907 1
# [0.9810900865608124, 0.19355165215543305] 3.810789852103117 3.043774640535979 1
# >epoch=111, lrate=0.050, error=6.475
# >epoch=112, lrate=0.050, error=6.283
# >epoch=113, lrate=0.050, error=8.163
# >epoch=114, lrate=0.050, error=6.328
# >epoch=115, lrate=0.050, error=6.398
# >epoch=116, lrate=0.050, error=6.312
# >epoch=117, lrate=0.050, error=6.249
# >epoch=118, lrate=0.050, error=6.211
# >epoch=119, lrate=0.050, error=6.269
# >epoch=120, lrate=0.050, error=6.220
# Layer ---------------
# [0.6352887290802831, 0.7722747119410027] 1.6805519436858698 2.3375181470403192 0
# [0.6620715468500532, 0.749440635975644] 4.431755461214623 9.249589587532638 1
# [0.9820150727288074, 0.18880253423467402] 3.840332823990581 3.1609502904383864 1
# >epoch=121, lrate=0.050, error=6.203
# >epoch=122, lrate=0.050, error=6.236
# >epoch=123, lrate=0.050, error=6.199
# >epoch=124, lrate=0.050, error=6.219
# >epoch=125, lrate=0.050, error=6.195
# >epoch=126, lrate=0.050, error=6.224
# >epoch=127, lrate=0.050, error=6.191
# >epoch=128, lrate=0.050, error=6.216
# >epoch=129, lrate=0.050, error=6.188
# >epoch=130, lrate=0.050, error=6.216
# Layer ---------------
# [0.6354109518064148, 0.7721741528466658] 1.643915023182131 2.3486819405840085 0
# [0.6660351969031897, 0.7459203151048571] 4.43677142961019 9.277468537927396 1
# [0.9821963633750631, 0.18785713660332748] 3.852436800338784 3.215533431459133 1
# >epoch=131, lrate=0.050, error=6.186
# >epoch=132, lrate=0.050, error=6.211
# >epoch=133, lrate=0.050, error=6.183
# >epoch=134, lrate=0.050, error=6.210
# >epoch=135, lrate=0.050, error=6.181
# >epoch=136, lrate=0.050, error=6.207
# >epoch=137, lrate=0.050, error=6.179
# >epoch=138, lrate=0.050, error=6.206
# >epoch=139, lrate=0.050, error=6.177
# >epoch=140, lrate=0.050, error=6.204
# Layer ---------------
# [0.6355140702373726, 0.772089286630975] 1.6114509788858336 2.358646841155416 0
# [0.6648914937885485, 0.7469399584221161] 4.438580481845191 9.303331132250658 1
# [0.9822827369673056, 0.18740497500338504] 3.860140756219904 3.2519414314578303 1
# >epoch=141, lrate=0.050, error=6.176
# >epoch=142, lrate=0.050, error=6.203
# >epoch=143, lrate=0.050, error=6.174
# >epoch=144, lrate=0.050, error=6.201
# >epoch=145, lrate=0.050, error=6.173
# >epoch=146, lrate=0.050, error=6.200
# >epoch=147, lrate=0.050, error=6.171
# >epoch=148, lrate=0.050, error=6.199
# >epoch=149, lrate=0.050, error=6.170
# [0, 1, 1]
# [2.7810836, 2.550537003, 0] [0.9333499932891419, 0.001060364237570843, 0.012929064448155727]
# [1.465489372, 2.362125076, 0] [0.8824757199284925, 3.014314303121704e-08, 2.5901205473729063e-05]
# [3.396561688, 4.400293529, 0] [0.8174500659444233, 0.9999387153145078, 0.0028023129986943307]
# [1.38807019, 1.850220317, 0] [0.8097542478548887, 2.321808693899556e-10, 2.49168353930992e-05]
# [3.06407232, 3.005305973, 0] [0.933843546870373, 0.16164691026264766, 0.0211996622064578]
# [7.627531214, 2.759262235, 1] [3.2741245583722504e-05, 0.999997380613272, 0.9847851118584987]
# [5.332441248, 2.088626775, 1] [0.1624448003188528, 0.8609673106079359, 0.9751332768640574]
# [6.922596716, 1.77106367, 1] [0.0004324278003880068, 0.972594834851879, 0.9948846247082709]
# [8.675418651, -0.242068655, 1] [4.0946968234002877e-10, 8.34108731930789e-07, 0.9397090643448026]
# [7.673756466, 3.508563011, 1] [2.426374532932149e-05, 0.9999999899337068, 0.9423536586275257]
# [0.673756466, 5.508563011, 1] [0.1291747445517685, 0.04929932542833602, 6.56871788344756e-11]
# [1.373756466, 6.108563011, 1] [0.0743893930758776, 0.9954036118038408, 2.9776790929072436e-10]
# [1.93756466, 7.108563011, 1] [0.0036990788334435184, 0.9999984057332241, 3.139176991716112e-11]
# accuray: 0.8461538461538461

# %%
T = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1],
    [0.673756466,5.508563011,1],
    [1.373756466,6.108563011,1],
    [1.93756466,7.108563011,1] 
    ]
n_inputs = len(T[0]) - 1
network = SSNN_network(n_inputs, [],['L','L'],[0,1])
#network.print_network_param()
network.train_network( T, 0.05, 150, 10)
network.test_network(T)
# Out:
# line [-2, 8] [0.5014595008994197, -0.5714077229983436] w [0.06864483126408882, 0.6398259704001377]
# line [-2, 8] [1.2137695760891782, 0.23623952409786625] w [0.0628384247102255, 0.6428285716865509]
# Layer ---------------
# [0.06864483126408882, 0.6398259704001377] 0.1835571492511623
# [0.0628384247102255, 0.6428285716865509] 0.6545689135335458
# >epoch=0, lrate=0.050, error=10.482
# line [-2, 8] [-0.12300937214393948, 1.8559562245380576] w [-0.11441004362553149, 0.5781305335340612]
# line [-2, 8] [1.28329621571959, 0.1919855577485083] w [0.06586425611428406, 0.6035335184642665]
# Layer ---------------
# [-0.11441004362553149, 0.5781305335340612] 0.15770461330379737
# [0.06586425611428406, 0.6035335184642665] 0.6427837680765544
# >epoch=1, lrate=0.050, error=8.654
# >epoch=2, lrate=0.050, error=7.722
# >epoch=3, lrate=0.050, error=7.558
# >epoch=4, lrate=0.050, error=7.441
# >epoch=5, lrate=0.050, error=7.294
# >epoch=6, lrate=0.050, error=7.113
# >epoch=7, lrate=0.050, error=6.905
# >epoch=8, lrate=0.050, error=6.686
# >epoch=9, lrate=0.050, error=6.470
# >epoch=10, lrate=0.050, error=6.272
# line [-2, 8] [-5.9164481278115995, 31.325422516373077] w [-0.38473653801483404, 0.10330752224845899]
# line [-2, 8] [6.816465309677217, -4.665433619138955] w [0.12112802586416065, 0.10549476755988951]
# Layer ---------------
# [-0.38473653801483404, 0.10330752224845899] 0.1582594794339177
# [0.12112802586416065, 0.10549476755988951] 0.47684537169612695
# >epoch=11, lrate=0.050, error=6.105
# >epoch=12, lrate=0.050, error=5.977
# >epoch=13, lrate=0.050, error=5.884
# >epoch=14, lrate=0.050, error=5.816
# >epoch=15, lrate=0.050, error=5.766
# >epoch=16, lrate=0.050, error=5.728
# >epoch=17, lrate=0.050, error=5.698
# >epoch=18, lrate=0.050, error=5.674
# >epoch=19, lrate=0.050, error=5.655
# >epoch=20, lrate=0.050, error=5.638
# line [-2, 8] [2.48977260876282, -22.149267573493837] w [-0.26379410147963606, -0.10706346494357455]
# line [-2, 8] [18.7568644348629, -30.435716650428006] w [0.1902513033205488, 0.03867479589873277]
# Layer ---------------
# [-0.26379410147963606, -0.10706346494357455] 0.26102452054352177
# [0.1902513033205488, 0.03867479589873277] 0.3449152970774247
# >epoch=21, lrate=0.050, error=5.623
# >epoch=22, lrate=0.050, error=5.608
# >epoch=23, lrate=0.050, error=5.595
# >epoch=24, lrate=0.050, error=5.581
# >epoch=25, lrate=0.050, error=5.569
# >epoch=26, lrate=0.050, error=5.556
# >epoch=27, lrate=0.050, error=5.543
# >epoch=28, lrate=0.050, error=5.531
# >epoch=29, lrate=0.050, error=5.519
# >epoch=30, lrate=0.050, error=5.507
# line [-2, 8] [1.1580465777264244, -18.64768125311583] w [-0.2649596483051421, -0.1337793039307228]
# line [-2, 8] [12.08068075451694, -27.269121473311184] w [0.205495749253313, 0.05222281628342891]
# Layer ---------------
# [-0.2649596483051421, -0.1337793039307228] 0.37499663152268753
# [0.205495749253313, 0.05222281628342891] 0.2198956731152676
# >epoch=31, lrate=0.050, error=5.494
# >epoch=32, lrate=0.050, error=5.482
# >epoch=33, lrate=0.050, error=5.470
# >epoch=34, lrate=0.050, error=5.458
# >epoch=35, lrate=0.050, error=5.446
# >epoch=36, lrate=0.050, error=5.435
# >epoch=37, lrate=0.050, error=5.423
# >epoch=38, lrate=0.050, error=5.411
# >epoch=39, lrate=0.050, error=5.399
# >epoch=40, lrate=0.050, error=5.388
# line [-2, 8] [0.43029813248477566, -17.927831984768442] w [-0.27570834960442137, -0.15018324188981913]
# line [-2, 8] [7.738251667512419, -23.928828783794312] w [0.21774386808125393, 0.06876032301622198]
# Layer ---------------
# [-0.27570834960442137, -0.15018324188981913] 0.4867931306931442
# [0.21774386808125393, 0.06876032301622198] 0.09659694807646445
# >epoch=41, lrate=0.050, error=5.376
# >epoch=42, lrate=0.050, error=5.364
# >epoch=43, lrate=0.050, error=5.353
# >epoch=44, lrate=0.050, error=5.341
# >epoch=45, lrate=0.050, error=5.330
# >epoch=46, lrate=0.050, error=5.318
# >epoch=47, lrate=0.050, error=5.307
# >epoch=48, lrate=0.050, error=5.296
# >epoch=49, lrate=0.050, error=5.284
# >epoch=50, lrate=0.050, error=5.273
# line [-2, 8] [-0.13603049123882713, -17.418061951237675] w [-0.2866597257968099, -0.1658715449397921]
# line [-2, 8] [5.0914067068985895, -21.819350006513893] w [0.22972086736385183, 0.0853639568036961]
# Layer ---------------
# [-0.2866597257968099, -0.1658715449397921] 0.595883039334323
# [0.22972086736385183, 0.0853639568036961] -0.02481911252996381
# >epoch=51, lrate=0.050, error=5.262
# >epoch=52, lrate=0.050, error=5.251
# >epoch=53, lrate=0.050, error=5.240
# >epoch=54, lrate=0.050, error=5.228
# >epoch=55, lrate=0.050, error=5.217
# >epoch=56, lrate=0.050, error=5.207
# >epoch=57, lrate=0.050, error=5.196
# >epoch=58, lrate=0.050, error=5.185
# >epoch=59, lrate=0.050, error=5.174
# >epoch=60, lrate=0.050, error=5.163
# line [-2, 8] [-0.5924348430630294, -16.999901193620996] w [-0.29739980471639965, -0.1812588234906153]
# line [-2, 8] [3.3273974605788372, -20.38321134076441] w [0.2415227242083269, 0.10186272576630095]
# Layer ---------------
# [-0.29739980471639965, -0.1812588234906153] 0.7021836520812513
# [0.2415227242083269, 0.10186272576630095] -0.1441076733742255
# >epoch=61, lrate=0.050, error=5.152
# >epoch=62, lrate=0.050, error=5.142
# >epoch=63, lrate=0.050, error=5.131
# >epoch=64, lrate=0.050, error=5.120
# >epoch=65, lrate=0.050, error=5.110
# >epoch=66, lrate=0.050, error=5.099
# >epoch=67, lrate=0.050, error=5.089
# >epoch=68, lrate=0.050, error=5.079
# >epoch=69, lrate=0.050, error=5.068
# >epoch=70, lrate=0.050, error=5.058
# line [-2, 8] [-0.9669137773495965, -16.64874530449182] w [-0.3079066598880034, -0.19634610877886072]
# line [-2, 8] [2.0744309158378105, -19.340160867077667] w [0.2531358910547775, 0.11820719891412027]
# Layer ---------------
# [-0.3079066598880034, -0.19634610877886072] 0.8056630774832698
# [0.2531358910547775, 0.11820719891412027] -0.2610591142075143
# >epoch=71, lrate=0.050, error=5.048
# >epoch=72, lrate=0.050, error=5.038
# >epoch=73, lrate=0.050, error=5.027
# >epoch=74, lrate=0.050, error=5.017
# >epoch=75, lrate=0.050, error=5.007
# >epoch=76, lrate=0.050, error=4.997
# >epoch=77, lrate=0.050, error=4.987
# >epoch=78, lrate=0.050, error=4.977
# >epoch=79, lrate=0.050, error=4.968
# >epoch=80, lrate=0.050, error=4.958
# line [-2, 8] [-1.2787053894759015, -16.349619569764783] w [-0.3181776567294775, -0.21112034274975786]
# line [-2, 8] [1.1431189669084598, -18.546512849280656] w [0.26454550610779637, 0.13435777193674237]
# Layer ---------------
# [-0.3181776567294775, -0.21112034274975786] 0.9063160335610699
# [0.26454550610779637, 0.13435777193674237] -0.37550409476314134
# >epoch=81, lrate=0.050, error=4.948
# >epoch=82, lrate=0.050, error=4.938
# >epoch=83, lrate=0.050, error=4.929
# >epoch=84, lrate=0.050, error=4.919
# >epoch=85, lrate=0.050, error=4.909
# >epoch=86, lrate=0.050, error=4.900
# >epoch=87, lrate=0.050, error=4.890
# >epoch=88, lrate=0.050, error=4.881
# >epoch=89, lrate=0.050, error=4.872
# >epoch=90, lrate=0.050, error=4.862
# line [-2, 8] [-1.5415654443873679, -16.091815638500858] w [-0.3282126386805318, -0.22557181787383618]
# line [-2, 8] [0.4269835236195602, -17.92138967896267] w [0.27573978929855736, 0.15028023806478472]
# Layer ---------------
# [-0.3282126386805318, -0.22557181787383618] 1.0041589970230103
# [0.27573978929855736, 0.15028023806478472] -0.4873123930178266
# >epoch=91, lrate=0.050, error=4.853
# >epoch=92, lrate=0.050, error=4.844
# >epoch=93, lrate=0.050, error=4.835
# >epoch=94, lrate=0.050, error=4.826
# >epoch=95, lrate=0.050, error=4.816
# >epoch=96, lrate=0.050, error=4.807
# >epoch=97, lrate=0.050, error=4.798
# >epoch=98, lrate=0.050, error=4.790
# >epoch=99, lrate=0.050, error=4.781
# >epoch=100, lrate=0.050, error=4.772
# line [-2, 8] [-1.7655833610935592, -15.867405347384972] w [-0.3380129086345096, -0.23969449406119075]
# line [-2, 8] [-0.13842187880853277, -17.41575290040346] w [0.2867099398956871, 0.16594573521646863]
# Layer ---------------
# [-0.3380129086345096, -0.23969449406119075] 1.0992264277291965
# [0.2867099398956871, 0.16594573521646863] -0.5963904002403011
# >epoch=101, lrate=0.050, error=4.763
# >epoch=102, lrate=0.050, error=4.754
# >epoch=103, lrate=0.050, error=4.746
# >epoch=104, lrate=0.050, error=4.737
# >epoch=105, lrate=0.050, error=4.728
# >epoch=106, lrate=0.050, error=4.720
# >epoch=107, lrate=0.050, error=4.711
# >epoch=108, lrate=0.050, error=4.703
# >epoch=109, lrate=0.050, error=4.694
# >epoch=110, lrate=0.050, error=4.686
# line [-2, 8] [-1.9583185720055947, -15.670380904352713] w [-0.3475809461036243, -0.25348553534771473]
# line [-2, 8] [-0.5943737578477877, -16.99809736474964] w [0.2974498164792111, 0.18133066833317]
# Layer ---------------
# [-0.3475809461036243, -0.25348553534771473] 1.191567323813459
# [0.2974498164792111, 0.18133066833317] -0.7026778237086593
# >epoch=111, lrate=0.050, error=4.678
# >epoch=112, lrate=0.050, error=4.669
# >epoch=113, lrate=0.050, error=4.661
# >epoch=114, lrate=0.050, error=4.653
# >epoch=115, lrate=0.050, error=4.645
# >epoch=116, lrate=0.050, error=4.637
# >epoch=117, lrate=0.050, error=4.629
# >epoch=118, lrate=0.050, error=4.621
# >epoch=119, lrate=0.050, error=4.613
# >epoch=120, lrate=0.050, error=4.605
# line [-2, 8] [-2.1255394449579232, -15.496099578838757] w [-0.3569201851975296, -0.26694482626281174]
# line [-2, 8] [-0.9685171883082158, -16.64722347848653] w [0.3079556037821128, 0.19641646324800846]
# Layer ---------------
# [-0.3569201851975296, -0.26694482626281174] 1.2812421282441053
# [0.3079556037821128, 0.19641646324800846] -0.8061439282866307
# >epoch=121, lrate=0.050, error=4.597
# >epoch=122, lrate=0.050, error=4.589
# >epoch=123, lrate=0.050, error=4.581
# >epoch=124, lrate=0.050, error=4.574
# >epoch=125, lrate=0.050, error=4.566
# >epoch=126, lrate=0.050, error=4.558
# >epoch=127, lrate=0.050, error=4.551
# >epoch=128, lrate=0.050, error=4.543
# >epoch=129, lrate=0.050, error=4.536
# >epoch=130, lrate=0.050, error=4.528
# line [-2, 8] [-2.27171815800055, -15.34091221474488] w [-0.36603482181154806, -0.2800745173897365]
# line [-2, 8] [-1.2800494496708539, -16.348315170918735] w [0.31822548956904484, 0.2111891942018998]
# Layer ---------------
# [-0.36603482181154806, -0.2800745173897365] 1.3683200103706012
# [0.31822548956904484, 0.2111891942018998] -0.9067835909526626
# >epoch=131, lrate=0.050, error=4.521
# >epoch=132, lrate=0.050, error=4.513
# >epoch=133, lrate=0.050, error=4.506
# >epoch=134, lrate=0.050, error=4.499
# >epoch=135, lrate=0.050, error=4.491
# >epoch=136, lrate=0.050, error=4.484
# >epoch=137, lrate=0.050, error=4.477
# >epoch=138, lrate=0.050, error=4.470
# >epoch=139, lrate=0.050, error=4.463
# >epoch=140, lrate=0.050, error=4.456
# line [-2, 8] [-2.400370671088564, -15.201907979946126] w [-0.37492964687952407, -0.2928786112431239]
# line [-2, 8] [-1.5427051956102122, -16.09068539063918] w [0.3282593616825636, 0.22563913153712534]
# Layer ---------------
# [-0.37492964687952407, -0.2928786112431239] 1.4528765223761921
# [0.3282593616825636, 0.22563913153712534] -1.0046133839204265
# >epoch=141, lrate=0.050, error=4.449
# >epoch=142, lrate=0.050, error=4.442
# >epoch=143, lrate=0.050, error=4.435
# >epoch=144, lrate=0.050, error=4.428
# >epoch=145, lrate=0.050, error=4.421
# >epoch=146, lrate=0.050, error=4.414
# >epoch=147, lrate=0.050, error=4.407
# >epoch=148, lrate=0.050, error=4.401
# >epoch=149, lrate=0.050, error=4.394
# [0, 1]
# [2.7810836, 2.550537003, 0] [0.4223175668683544, 0.6118607990277669]
# [1.465489372, 2.362125076, 0] [0.5615808134290239, 0.49169022342230595]
# [3.396561688, 4.400293529, 0] [0.24760898126943384, 0.7509200597682879]
# [1.38807019, 1.850220317, 0] [0.606565297492309, 0.45478423840210674]
# [3.06407232, 3.005305973, 0] [0.36357309138923766, 0.6590207268763024]
# [7.627531214, 2.759262235, 1] [0.09693704638427143, 0.8945965881086491]
# [5.332441248, 2.088626775, 1] [0.24061287855961674, 0.7694260699446267]
# [6.922596716, 1.77106367, 1] [0.15957729273565252, 0.8409618404151761]
# [8.675418651, -0.242068655, 1] [0.15186847833193118, 0.8552521368665971]
# [7.673756466, 3.508563011, 1] [0.07746443899073353, 0.9115545538831247]
# [0.673756466, 5.508563011, 1] [0.39979864809864746, 0.6106078004932437]
# [1.373756466, 6.108563011, 1] [0.298027773191357, 0.696111289647582]
# [1.93756466, 7.108563011, 1] [0.20155014779423722, 0.7785548711268329]
# accuray: 0.7692307692307693
